# %%
import os

def print_subfolders_files(root_folder):
    """
    Print the names of all subfolders and files in the root_folder directory.
    """
    for dirpath, dirnames, filenames in os.walk(root_folder):
        # print the current directory path
        # print("Current directory:", dirpath)
        
        # print all subdirectories in the current directory
        # print("Subdirectories:")
        for dirname in dirnames:
            # print(os.path.join(dirpath, dirname))
            pass
        
        # print all files in the current directory
        # print("Files:")
        for filename in filenames:
            if filename[-17:] != "CURATION_USER.tsv":
                print(os.path.join(dirpath, filename)[-25:])
            
        # print a separator for readability
        # print("-" * 40)

# example usage:
source_folder_list = \
    "/Users/n2t2k/Documents/Studying/Master/Thesis/InProgress/Coding/ORIGIN_RUN_ALL_edge-oriented-graph-master-studying/dataProcessingOfficialCleaned/VLSP2020_RE_dev"

# print_subfolders_files(source_folder_list)

# %%
import os

def rename_files_keep_subfolders(root_folder, new_prefix):
    """
    Rename all files in root_folder and its subdirectories
    with a new prefix specified by new_prefix, but keep the
    subfolder names in the new filenames.
    """
    for dirpath, dirnames, filenames in os.walk(root_folder):
        for filename in filenames:
            # print(dirpath, dirnames, filenames)
            # get the full path of the file
            old_path = os.path.join(dirpath, filename)
            
            # construct the new filename with the subfolder name and the specified prefix
            subfolder_name = os.path.relpath(dirpath, root_folder)
            new_filename = f"{subfolder_name}/{new_prefix}"
            if filename != "CURATION_USER.tsv":
                # print(f"filename<{filename}>",)

                new_filename = f"{new_prefix}"
                new_path = os.path.join(dirpath, new_filename)
                
                # rename the file
                # os.rename(old_path, new_path)
                print(f"Renamed {old_path[-100:]}\n{new_path[-100:]}")
                print(f"len {len(old_path)}\n{len(new_path)}")
                print("* "*50)
                
# example usage:
# rename_files_keep_subfolders(source_folder_list, "CURATION_USER.tsv")

# %%
import os
import shutil

def copy_folders_from_file(source_file, destination_folder, source_folder_list_path):
    with open(source_file, 'r') as f:
        folders = f.read().strip().split(',')
    # print(destination_folder)
    for folder in folders:
        folder_path = f"{source_folder_list_path}/{folder}/"
        # print(folder)
        # print(os.path.isdir(folder))
        # print(os.path.isdir(folder))
        # folder_path = os.path.join(folder.strip(), '')
        destination_path = os.path.join(destination_folder, folder.strip())
        # print("destination_path ", destination_path)
        # print("folder_path ", folder_path)
        try:
            shutil.copytree(folder_path, destination_path)
        except:
            print(f"{folder} existed")

source_file = \
    "/Users/n2t2k/Documents/Studying/Master/Thesis/InProgress/Coding/ORIGIN_RUN_ALL_edge-oriented-graph-master-studying/dataProcessingOfficialCleaned/dev_processed/double_quote_err.txt"
destination_folder = \
    "/Users/n2t2k/Documents/Studying/Master/Thesis/InProgress/Coding/ORIGIN_RUN_ALL_edge-oriented-graph-master-studying/dataProcessingOfficialCleaned/dev_processed/double_quote_file_check/double_quote_files"
source_folder_list = \
    "/Users/n2t2k/Documents/Studying/Master/Thesis/InProgress/Coding/ORIGIN_RUN_ALL_edge-oriented-graph-master-studying/dataProcessingOfficialCleaned/VLSP2020_RE_dev"

copy_folders_from_file(source_file, destination_folder, source_folder_list)

# %%
# import os


# def find_file_has_ent_in_double_quote_file_check(root_dir):
#     # Root directory to search in

#     # List of words to search for in the files
#     words_to_search = ["ORGANIZATION", "PERSON", "LOCATION"]

#     # List to store the names of files that contain the words
#     files_containing_words = set()

#     # Traverse through all subdirectories and files
#     for dirpath, dirnames, filenames in os.walk(root_dir):
#         # print(dirpath)
#         found = False
#         for filename in filenames:
#             # print("filename ", filename)
#             # Check if file has the extension you want to search in (e.g. ".txt")
           
#             with open(os.path.join(dirpath, filename), "r") as f:
#                 lines = f.readlines()
#                 # Check each line for the words to search for
#                 for line in lines:
#                     # print(line)
#                     for word in words_to_search:
#                         if word in line:
#                             # If word is found, add file name to list
#                             files_containing_words.add(dirpath[-14:]) # 23351951.conll
#                             found = True
#                             break  # Stop searching for other words in the same line
#                     if found:
#                         break
#             if found:
#                 break
#     return files_containing_words                          

# double_quote_file_check = \
#     "/Users/n2t2k/Documents/Studying/Master/Thesis/InProgress/Coding/ORIGIN_RUN_ALL_edge-oriented-graph-master-studying/dataProcessingOfficialCleaned/double_quote_file_check//Users/n2t2k/Documents/Studying/Master/Thesis/InProgress/Coding/ORIGIN_RUN_ALL_edge-oriented-graph-master-studying/dataProcessingOfficialCleaned/dev_processed/double_quote_file_check/double_quote_files"

# has_ent = find_file_has_ent_in_double_quote_file_check(double_quote_file_check)

# # Print list of files containing the words
# from pprint import pprint
# pprint(has_ent)

# %%
# import os
# import shutil

# def copy_folders_from_file(source_file_list, destination_folder, source_folder_list_path):
#     # print(destination_folder)
#     for folder in source_file_list:
#         folder_path = f"{source_folder_list_path}/{folder}/"
#         # print(folder)
#         # print(os.path.isdir(folder))
#         # print(os.path.isdir(folder))
#         # folder_path = os.path.join(folder.strip(), '')
#         destination_path = os.path.join(destination_folder, folder.strip())
#         # print("destination_path ", destination_path)
#         # print("folder_path ", folder_path)
#         try:
#             shutil.copytree(folder_path, destination_path)
#         except:
#             print(f"{folder} existed")
# source_folder_list = \
#     "/Users/n2t2k/Documents/Studying/Master/Thesis/InProgress/Coding/ORIGIN_RUN_ALL_edge-oriented-graph-master-studying/dataProcessingOfficialCleaned/double_quote_file_check//Users/n2t2k/Documents/Studying/Master/Thesis/InProgress/Coding/ORIGIN_RUN_ALL_edge-oriented-graph-master-studying/dataProcessingOfficialCleaned/dev_processed/double_quote_file_check/double_quote_files"
# destination_folder = \
#     "/Users/n2t2k/Documents/Studying/Master/Thesis/InProgress/Coding/ORIGIN_RUN_ALL_edge-oriented-graph-master-studying/dataProcessingOfficialCleaned/dev_processed/double_quote_file_check/double_quote_has_ent"

# copy_folders_from_file(has_ent, destination_folder, source_folder_list)

# %%
import os
import shutil

def copy_folders_from_file(source_file, destination_folder, source_folder_list_path):
    with open(source_file, 'r') as f:
        folders = f.read().strip().split(',')
    # print(destination_folder)
    for folder in folders:
        folder_path = f"{source_folder_list_path}/{folder}/"
        # print(folder)
        # print(os.path.isdir(folder))
        # print(os.path.isdir(folder))
        # folder_path = os.path.join(folder.strip(), '')
        destination_path = os.path.join(destination_folder, folder.strip())
        # print("destination_path ", destination_path)
        # print("folder_path ", folder_path)
        try:
            shutil.copytree(folder_path, destination_path)
        except:
            print(f"{folder} existed")

source_file = \
    "/Users/n2t2k/Documents/Studying/Master/Thesis/InProgress/Coding/ORIGIN_RUN_ALL_edge-oriented-graph-master-studying/dataProcessingOfficialCleaned/dev_processed/data_errors_files.txt"
destination_folder = \
    "/Users/n2t2k/Documents/Studying/Master/Thesis/InProgress/Coding/ORIGIN_RUN_ALL_edge-oriented-graph-master-studying/dataProcessingOfficialCleaned/dev_processed/error_file_check/error_files"
source_folder_list = \
    "/Users/n2t2k/Documents/Studying/Master/Thesis/InProgress/Coding/ORIGIN_RUN_ALL_edge-oriented-graph-master-studying/dataProcessingOfficialCleaned/VLSP2020_RE_dev"

# copy_folders_from_file(source_file, destination_folder, source_folder_list)
